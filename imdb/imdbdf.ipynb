# %%
import numpy as np
import pandas as pd
import os

# %%
data =pd.read_csv('film.csv')
df = pd.DataFrame(data)
df.index = df.index +1
df.head(5)
# Out:
#           Director  Film_Count Film_Country         Film_Date  \
# 1   Frank Darabont         NaN          USA   14 October 1994
# 2    Isao Takahata         NaN          USA      26 July 1989
# 3     Ridley Scott         NaN          USA        5 May 2000
# 4  Robert Zemeckis         NaN          USA       3 July 1985
# 5   Frank Darabont         NaN          USA  10 December 1999
#
#                   Film_Name  Film_Rate  \
# 1  The Shawshank Redemption        9.3
# 2    Grave of the Fireflies        8.5
# 3                 Gladiator        8.5
# 4        Back to the Future        8.5
# 5            The Green Mile        8.6
#
#                                              Stars
# 1            Tim Robbins,Morgan Freeman,Bob Gunton
# 2  Tsutomu Tatsumi,Ayano Shiraishi,Akemi Yamaguchi
# 3     Russell Crowe,Joaquin Phoenix,Connie Nielsen
# 4    Michael J. Fox,Christopher Lloyd,Lea Thompson
# 5      Tom Hanks,Michael Clarke Duncan,David Morse

# %%
df.sort_values(by='Film_Rate', ascending =False, inplace= True)
df.set_index(np.arange(1,(len(df))+1), inplace=True)
df.to_excel("Top_330_Films.xlsx",sheet_name='Top_330_Films')
df
# Out:
#                  Director Film_Country         Film_Date  \
# 1          Frank Darabont          USA   14 October 1994
# 2    Francis Ford Coppola          USA     24 March 1972
# 3    Francis Ford Coppola          USA  18 December 1974
# 4       Christopher Nolan          USA      18 July 2008
# 5            Sidney Lumet          USA     10 April 1957
# ..                    ...          ...               ...
# 314          Furkan Kopuz          Tur  26 December 2015
# 315         Peter Jackson          USA  17 December 2014
# 316     Christopher Nolan          USA       24 May 2002
# 317           Faruk Aksoy          USA     25 April 2012
# 318          Furkan Kopuz          Tur       19 May 2013
#
#                                      Film_Name  Film_Rate  \
# 1                     The Shawshank Redemption        9.3
# 2                                The Godfather        9.2
# 3                       The Godfather: Part II        9.0
# ...
